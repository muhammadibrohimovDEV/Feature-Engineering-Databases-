# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadibrohimovDEV/Feature-Engineering-Databases-/blob/main/northwind_sqlite_practise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sqlite3 as sql

# %%
# !wget "https://github.com/jpwhite3/northwind-SQLite3/archive/refs/heads/master.zip"
# Out:
# --2025-04-11 10:01:08--  https://github.com/jpwhite3/northwind-SQLite3/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/jpwhite3/northwind-SQLite3/zip/main [following]
# --2025-04-11 10:01:08--  https://codeload.github.com/jpwhite3/northwind-SQLite3/zip/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip.1’
#
# master.zip.1            [  <=>               ]  10.97M  10.4MB/s    in 1.1s
#
# 2025-04-11 10:01:09 (10.4 MB/s) - ‘master.zip.1’ saved [11500885]

# %%
# !unzip master.zip
# Out:
# Archive:  master.zip
# 4f56e7f5906dfd23b25244c5bfe8fb5da6402efd
#    creating: northwind-SQLite3-main/
#  extracting: northwind-SQLite3-main/.gitignore
#   inflating: northwind-SQLite3-main/CODE_OF_CONDUCT.md
#   inflating: northwind-SQLite3-main/CONTRIBUTING.md
#   inflating: northwind-SQLite3-main/LICENSE
#   inflating: northwind-SQLite3-main/README.md
#    creating: northwind-SQLite3-main/dist/
#   inflating: northwind-SQLite3-main/dist/northwind.db
#    creating: northwind-SQLite3-main/docs/
#   inflating: northwind-SQLite3-main/docs/Northwind_ERD.png
#   inflating: northwind-SQLite3-main/makefile
#    creating: northwind-SQLite3-main/src/
#   inflating: northwind-SQLite3-main/src/create.sql
#   inflating: northwind-SQLite3-main/src/populate.py
#   inflating: northwind-SQLite3-main/src/report.sql
#   inflating: northwind-SQLite3-main/src/update.sql

# %%
db = sql.connect("/content/northwind-SQLite3-main/dist/northwind.db")
dbc = db.cursor()

# %%
def take_info_db():
  info = pd.read_sql("SELECT name FROM sqlite_master WHERE type = 'table';", db)
  return info

# %%
def read_sqlite_db(query):
  df = pd.read_sql(query, db)
  return df

# %%
df = read_sqlite_db("SELECT * FROM customers;")
df.head()
# Out:
#   CustomerID                         CompanyName         ContactName  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                  Berglunds snabbköp  Christina Berglund
#
#            ContactTitle                        Address         City  \
# 0  Sales Representative                  Obere Str. 57       Berlin
# 1                 Owner  Avda. de la Constitución 2222  México D.F.
# 2                 Owner                Mataderos  2312  México D.F.
# 3  Sales Representative                120 Hanover Sq.       London
# 4   Order Administrator                Berguvsvägen  8        Luleå
#
#             Region PostalCode  Country           Phone             Fax
# ...
