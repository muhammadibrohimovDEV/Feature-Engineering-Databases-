# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadibrohimovDEV/Feature-Engineering-Databases-/blob/main/reading_writing_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv
# Out:
# --2025-03-14 03:06:20--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728047 (711K) [text/plain]
# Saving to: ‘merc.csv’
#
# merc.csv            100%[===================>] 710.98K  --.-KB/s    in 0.08s
#
# 2025-03-14 03:06:20 (8.32 MB/s) - ‘merc.csv’ saved [728047/728047]

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93 (from 1)
# Receiving objects: 100% (145/145), 9.72 MiB | 12.83 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
df = pd.read_csv('')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
pd.read_excel("uzbekistan.xlsx" , index_col = 0 , names = ['viloyat' , 'maydon' , 'aholi'])
# Out:
#                                maydon    aholi
# viloyat
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df2 = pd.read_csv("automobile_data.csv" , index_col = 'index' , nrows = 15)

# %%
df = pd.read_excel("uzbekistan.xlsx" , index_col = 0 , names = ['hudud' , 'maydon' , 'aholi'])

# %%
df
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %% [markdown]
# **Saving data(df , obj)***

# %%
df.to_csv("newuzb.csv")

# %%
obj = df['maydon']

# %%
obj
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
obj.to_csv("uzmaydon.csv")

# %%
pd.read_csv('uzmaydon.csv' , index_col = 0)
# Out:
#                                maydon
# hudud
# Andijon viloyati                 4200
# Buxoro viloyati                 39400
# Fargʻona viloyati                6800
# Jizzax viloyati                 20500
# Xorazm viloyati                  6300
# Namangan viloyati                7900
# Navoiy viloyati                110800
# Qashqadaryo viloyati            28400
# Qoraqalpogʻiston Respublikasi  160000
# Samarqand viloyati              16400
# Sirdaryo viloyati                5100
# Surxondaryo viloyati            20800
# Toshkent viloyati               15300

# %%
df = pd.read_csv("automobile_data.csv" , index_col = 'index' , nrows = 15)

# %%
df.to_excel('autodata.xlsx' , index = False , columns = ['company' , 'price' , 'length'])

# %% [markdown]
# **HDF5**

# %%
hdfobj = pd.HDFStore('data.h5')

# %%
hdfobj.put('uzdata' , df)

# %%
hdfobj.put('cardata' , df2)

# %%
hdfobj['uzdata']
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
hdfobj.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
hdfobj.close()

# %%
hdfobj['uzdata']
# Out:
# ---------------------------------------------------------------------------
# ClosedFileError                           Traceback (most recent call last)
# <ipython-input-53-fd0317cc26fd> in <cell line: 0>()
# ----> 1 hdfobj['uzdata']
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/pytables.py in __getitem__(self, key)
#     600
#     601     def __getitem__(self, key: str):
# --> 602         return self.get(key)
#     603
#     604     def __setitem__(self, key: str, value) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/pytables.py in get(self, key)
#     808             # GH#31167 Without this patch, pickle doesn't know how to unpickle
#     809             #  old DateOffset objects now that they are cdef classes.
# --> 810             group = self.get_node(key)
#     811             if group is None:
#     812                 raise KeyError(f"No object named {key} in the file")
#
# ...

# %%
data = pd.read_hdf('data.h5' , key = 'uzdata')

# %%
data
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
data.to_hdf('data.h5' , key = 'uzdata')
