# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadibrohimovDEV/Feature-Engineering-Databases-/blob/main/api_for_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# **Whether API**

# %%
data = requests.get("https://api.open-meteo.com/v1/forecast?latitude=41.3111&longitude=69.2797&hourly=temperature_2m")

# %%
data.status_code
# Out:
# 200

# %%
data = data.json()

# %%
df = pd.DataFrame(data['hourly'])

# %%
df
# Out:
#                  time  temperature_2m
# 0    2025-04-09T00:00            15.6
# 1    2025-04-09T01:00            15.3
# 2    2025-04-09T02:00            15.0
# 3    2025-04-09T03:00            15.5
# 4    2025-04-09T04:00            16.6
# ..                ...             ...
# 163  2025-04-15T19:00            13.2
# 164  2025-04-15T20:00            12.8
# 165  2025-04-15T21:00            12.5
# 166  2025-04-15T22:00            12.1
# 167  2025-04-15T23:00            11.6
#
# [168 rows x 2 columns]

# %% [markdown]
# **Transportation API**

# %%
data2 = requests.get("https://transport.opendata.ch/v1/locations?query=Zurich")

# %%
data2.status_code
# Out:
# 200

# %%
data2 = data2.json()

# %%
df3 = pd.DataFrame(data2['stations'])
df3
# Out:
#         id                 name score  \
# 0  8503000            Zürich HB  None
# 1  8503006      Zürich Oerlikon  None
# 2  8503020    Zürich Hardbrücke  None
# 3  8503003   Zürich Stadelhofen  None
# 4  8503016     Zürich Flughafen  None
# 5  8503001    Zürich Altstetten  None
# 6  8576193     Zürich, Bellevue  None
# 7  8591299  Zürich, Paradeplatz  None
# 8  8588078      Zürich, Central  None
# 9  8591276    Zürich, Milchbuck  None
#
#                                          coordinate distance   icon
# 0  {'type': 'WGS84', 'x': 47.377847, 'y': 8.540502}     None  train
# 1   {'type': 'WGS84', 'x': 47.411526, 'y': 8.54414}     None  train
# 2  {'type': 'WGS84', 'x': 47.385087, 'y': 8.517686}     None  train
# 3  {'type': 'WGS84', 'x': 47.366607, 'y': 8.548492}     None  train
# 4  {'type': 'WGS84', 'x': 47.450379, 'y': 8.562398}     None  train
# 5  {'type': 'WGS84', 'x': 47.391478, 'y': 8.488966}     None  train
# ...

# %% [markdown]
# **Open Food products**

# %%
data3 = requests.get("https://world.openfoodfacts.org/api/v0/product/737628064502.json")

# %%
data3.status_code
# Out:
# 200

# %%
data3 = data3.json()

# %%
df4 = pd.DataFrame(data3)

# %%
df4
# Out:
#                                   code  \
# _id                      0737628064502
# _keywords                0737628064502
# added_countries_tags     0737628064502
# additives_n              0737628064502
# additives_original_tags  0737628064502
# ...                                ...
# unknown_nutrients_tags   0737628064502
# update_key               0737628064502
# vitamins_prev_tags       0737628064502
# vitamins_tags            0737628064502
# weighers_tags            0737628064502
#
#                                                                    product  \
# _id                                                          0737628064502
# _keywords                [and, asia, beverage, cereal, food, gluten, in...
# added_countries_tags                                                    []
# additives_n                                                              1
# additives_original_tags                                          [en:e330]
# ...

# %% [markdown]
# **INFO About Uzbekistan API**

# %%
data5 = requests.get("https://restcountries.com/v3.1/name/uzbekistan")
data5.status_code
# Out:
# 200

# %%
data5 = data5.json()

# %%
df5 = pd.DataFrame(data5) # main dataframe

# %%
df5
# Out:
#                                                 name    tld cca2 ccn3 cca3  \
# 0  {'common': 'Uzbekistan', 'official': 'Republic...  [.uz]   UZ  860  UZB
#
#   cioc  independent               status  unMember  \
# 0  UZB         True  officially-assigned      True
#
#                                           currencies  ...            gini  \
# 0  {'UZS': {'name': 'Uzbekistani soʻm', 'symbol':...  ...  {'2003': 35.3}
#
#   fifa                                 car    timezones continents  \
# 0  UZB  {'signs': ['UZ'], 'side': 'right'}  [UTC+05:00]     [Asia]
#
#                                                flags  \
# 0  {'png': 'https://flagcdn.com/w320/uz.png', 'sv...
#
#                                           coatOfArms startOfWeek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
#
#                   capitalInfo                                  postalCode
# 0  {'latlng': [41.32, 69.25]}  {'format': '######', 'regex': '^(\d{6})$'}
#
# ...

# %% [markdown]
# **Reading HTML file like "https://en.wikipedia.org/wiki/Uzbekistan" about Uzbekistan **

# %%
df7 = pd.read_html("https://en.wikipedia.org/wiki/Uzbekistan")

# %%
df7 = pd.DataFrame(df7[0])

# %%
df7
# Out:
#    Republic of UzbekistanO‘zbekiston Respublikasi, Ўзбекистон Республикаси (Uzbek)  \
# 0                                        Flag  Emblem
# 1   Anthem: O‘zbekiston Respublikasining Davlat Ma...
# 2                      Location of Uzbekistan (green)
# 3                             Capitaland largest city
# 4                                  Official languages
# 5                                Recognized languages
# 6                                     Official script
# 7                             Ethnic groups (2021)[5]
# 8                                  Religion (2020)[6]
# 9                                          Demonym(s)
# 10                                         Government
# 11                                                NaN
# 12                                        • President
# 13                                   • Prime Minister
# 14                                        Legislature
# 15                                      • Upper house
# ...

# %%
df7.iat[48, 0]
# Out:
# 'Co-official in Karakalpakstan.[1]On 31 August 1991, the Supreme Soviet of the Uzbek SSR voted to declare the country independent from the Soviet Union. The next day was declared a national holiday by the Uzbek government, and became an Independence Day.dd.mm.yyyy format is used in Cyrillic scripts, including Russian.'
